# %% [markdown]
# <a href="https://colab.research.google.com/github/SouJooj/Atividade-t-picos-avan-ados/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================
# 1. INSTALAR ULTRALYTICS
# ============================
# !pip install ultralytics

from ultralytics import YOLO


# ============================
# 2. MONTAR O GOOGLE DRIVE
# ============================
from google.colab import drive
drive.mount('/content/drive')


# ============================
# 3. CRIAR PASTA DE BACKUP
# ============================
import os

backup_dir = "/content/drive/MyDrive/YOLO_BACKUP"
os.makedirs(backup_dir, exist_ok=True)


# ============================
# 4. CARREGAR MODELO BASE
# ============================
model = YOLO("yolov8s.pt")  # pode trocar para yolov8n.pt, yolov8m.pt etc.


# ============================
# 5. TREINAMENTO OTIMIZADO
# ============================
model.train(
    data="/content/residuos-sólidos-4/data.yaml",  # dataset
    epochs=200,            # mais épocas se dataset for grande
    imgsz=768,             # resolução
    batch=16,              # ajustar conforme GPU
    augment=True,          # aumento de dados
    optimizer='SGD',       # ou 'Adam'
    patience=15,           # early stopping
)


# ============================
# 6. SALVAR BEST.PT E LAST.PT NO DRIVE
# ============================
# !cp /content/runs/detect/train/weights/best.pt "/content/drive/MyDrive/YOLO_BACKUP/best.pt"
# !cp /content/runs/detect/train/weights/last.pt "/content/drive/MyDrive/YOLO_BACKUP/last.pt"

print("Backup concluído! Arquivos salvos na pasta YOLO_BACKUP no Google Drive.")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.5 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/YOLO_BACKUP/best.pt")

model.export(format = 'tflite')
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4102866495.py in <cell line: 0>()
#       2 drive.mount('/content/drive')
#       3
# ----> 4 from ultralytics import YOLO
#       5
#       6 model = YOLO("/content/drive/MyDrive/YOLO_BACKUP/best.pt")
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !cp /content/runs/detect/train/weights/best.pt "/content/drive/MyDrive/YOLO_BACKUP/best.pt"
# !cp /content/runs/detect/train/weights/last.pt "/content/drive/MyDrive/YOLO_BACKUP/last.pt"

print("Backup concluído! Arquivos salvos na pasta YOLO_BACKUP no Google Drive.")
# Out:
# cp: cannot stat '/content/runs/detect/train/weights/best.pt': No such file or directory
# cp: cannot stat '/content/runs/detect/train/weights/last.pt': No such file or directory
# Backup concluído! Arquivos salvos na pasta YOLO_BACKUP no Google Drive.
